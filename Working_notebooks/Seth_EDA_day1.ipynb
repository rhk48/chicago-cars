# %%
# !ls -a
# Out:
# .
# ..
# .git
# .gitignore
# .ipynb_checkpoints
# Dillon EDA.ipynb
# README.md
# Seth_EDA_day1.ipynb
# Working Notebook Karriti-2.ipynb
# data

# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.options.display.max_colwidth = 150
import numpy as np
import seaborn as sns
import warnings

# %%
df_ppl = pd.read_csv('data/People.csv')
df_cars = pd.read_csv('data/Vehicles.csv')
df_crashes = pd.read_csv('data/Crashes.csv')
# Out:
# C:\Users\sethk\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (12,13,20,21,22,23,24,25,26,27,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\sethk\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,21,40,41,42,44,48,49,50,53,55,58,59,61,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\sethk\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_crashes.columns = df_crashes.columns.str.strip().str.lower()
df_cars.columns = df_cars.columns.str.strip().str.lower()
df_ppl.columns = df_ppl.columns.str.strip().str.lower()

# %%
df_crashes.sample(5)
# Out:
#                                                                                                                          crash_record_id  \
# 318966  8eee15a2b7224704c562397310e4b5a7aa3059e1e145f15d338fa03bf180d6e20b145f959c2cc735483a221f1e6cb9a36e7478c4da4e83c0586ccdd4a46c3c22
# 457359  d5534efef6cbcebebac1955e158de516199549bb526e193cb4476e31e127c7b4239565f38168ba1c7c4f030f4655820b2551ce9c93b85e2425b61a63711fc305
# 254424  6e25952a763881d3161a84b01228dc7ae6bb6b90a59b7922af55e802dcad312f043d1d8237c4a6e6347532c52f4d0b81ebf2344d14bfa780439bb37671d7e08a
# 233618  63b562e6ec3f5cc66a7dfd08fb3cfa465c9c655bccba9d14eb0fb972e4b7b58a78a8bc6bdaf53aad7a8b53cdb95031ce49636aaa22f1e95dcb965432f6b56dfb
# 342796  9b26341dcc58f29f2f3f5249ed709dae169b34b022937560625f74632c99009b43291af5c0f062e7402d2bfe5d7216c0a4a70790863c8b91beee0617e52d8010
#
#            rd_no crash_date_est_i              crash_date  posted_speed_limit  \
# ...

# %%
df_crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541142 entries, 0 to 541141
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_record_id                541142 non-null  object
#  1   rd_no                          536550 non-null  object
#  2   crash_date_est_i               41029 non-null   object
#  3   crash_date                     541142 non-null  object
#  4   posted_speed_limit             541142 non-null  int64
#  5   traffic_control_device         541142 non-null  object
#  6   device_condition               541142 non-null  object
#  7   weather_condition              541142 non-null  object
#  8   lighting_condition             541142 non-null  object
#  9   first_crash_type               541142 non-null  object
#  10  trafficway_type                541142 non-null  object
#  11  lane_cnt                       198968 non-null  float64
# ...

# %%
df_1_fatal = df_crashes[df_crashes['injuries_fatal'] >= 1]
df_1_fatal
# Out:
#                                                                                                                          crash_record_id  \
# 31      09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
# 674     fdc5d4d1299102e75fd8c7997ea5c343a0b5e62a4f7bde7d2b6e5a02cd0d1c68711cc086eac0fabcbb7060de7b587328ca5dd9c56e8c8052c2595113fe818adf
# 1229    0b5c9ae3e936fd93a9c9dab85e638c0cb848a586a18551136fb3ae64d9ded27c813aee7ffb42704d65f640a3c54d2b023b17e13f255720cda15a41b8052ea867
# 2816    f4e1f0e49f5235e4d309257a1e506aed15ea89c1df66caeadc63e42e0719b244dac179fed7611cd9c7ed64f8b454ab0eb1975e83ce51677887a08bb19171d44f
# 3263    4f74423f38a9e168e7034e444a9145b813f4bc06ec8b81d54fa60e54fdc20d9622ce24f953b99d6e9b9b9cc3877f72e02b057c095cf0b17dec63af7f4598be3f
# ...                                                                                                                                  ...
# ...

# %%
test_ppl = df_ppl[(df_ppl['crash_record_id'] == '09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163')]
test_ppl
# Out:
#        person_id person_type  \
# 127663   O915417      DRIVER
# 127664   O915418  PEDESTRIAN
#
#                                                                                                                          crash_record_id  \
# 127663  09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
# 127664  09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
#
#            rd_no  vehicle_id              crash_date  seat_no     city state  \
# 127663  JD292201    867897.0  07/10/2020 02:55:00 AM      NaN      NaN   NaN
# 127664  JD292201         NaN  07/10/2020 02:55:00 AM      NaN  CHICAGO    IL
#
#        zipcode sex   age drivers_license_state drivers_license_class  \
# 127663     NaN   X   NaN                   NaN                   NaN
# 127664   60612   M  45.0                   NaN                   NaN
#
# ...

# %%
test_car = df_cars[(df_cars['crash_record_id'] == '09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163')]
test_car
# Out:
#         crash_unit_id  \
# 114031         915417
# 114032         915418
#
#                                                                                                                          crash_record_id  \
# 114031  09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
# 114032  09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
#
#            rd_no              crash_date  unit_no   unit_type  num_passengers  \
# 114031  JD292201  07/10/2020 02:55:00 AM        1      DRIVER             NaN
# 114032  JD292201  07/10/2020 02:55:00 AM        2  PEDESTRIAN             NaN
#
#         vehicle_id cmrc_veh_i     make                         model  \
# 114031    867897.0        NaN  UNKNOWN  OTHER (EXPLAIN IN NARRATIVE)
# 114032         NaN        NaN      NaN                           NaN
#
# ...

# %%
test_crash =  df_crashes[(df_crashes['crash_record_id'] == '09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163')]
test_crash
# Out:
#                                                                                                                      crash_record_id  \
# 31  09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
#
#        rd_no crash_date_est_i              crash_date  posted_speed_limit  \
# 31  JD292201              NaN  07/10/2020 02:55:00 AM                  30
#
#    traffic_control_device device_condition weather_condition  \
# 31         TRAFFIC SIGNAL          UNKNOWN           UNKNOWN
#
#         lighting_condition first_crash_type trafficway_type  lane_cnt  \
# 31  DARKNESS, LIGHTED ROAD       PEDESTRIAN        FOUR WAY       NaN
#
#              alignment roadway_surface_cond road_defect report_type  \
# 31  STRAIGHT AND LEVEL                  WET     UNKNOWN    ON SCENE
#
#                           crash_type intersection_related_i  \
# 31  INJURY AND / OR TOW DUE TO CRASH                      Y
#
# ...

# %%
df_ppl.sample(5)
# Out:
#        person_id person_type  \
# 284987   O188918      DRIVER
# 661505    O61709      DRIVER
# 315305   O223272      DRIVER
# 93843    O908987      DRIVER
# 518119    O45245      DRIVER
#
#                                                                                                                          crash_record_id  \
# 284987  28eb5fbc5a4b19b3225c2145acb359464079f5b3399fe0012bdc6bb04a6c22d8c8eb2a6cb639c8885d5b7a06b69bf6b1d1226e4c20cf6170eae5f0d5479794f6
# 661505  f4c9efbede101ef73777d59fbae869c91fd8f310988ceac50ada3c369ceeef79848ed079fa6bc6e0680b6a4b08916b392b105300fbb3dc393a2b9f5e1967fea7
# 315305  586296b377796ce73040eda8a7833f18e76f3c7d6f24332ae37e8202aebe010fe7a5aa953b82bbda51c0b46a21cbd43ef7f1de10a1915ae0c5fc03e0a34c5da0
# 93843   9bcbf69b1418fd7f929220a890c4a0f97384353d972ea71ffbc068374e6e5014d8edef89fe8037e841322868e35d03f982ddb386081f190aec765c6a7e5daeaf
# ...

# %%
df_ppl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195747 entries, 0 to 1195746
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   person_id              1195747 non-null  object
#  1   person_type            1195747 non-null  object
#  2   crash_record_id        1195747 non-null  object
#  3   rd_no                  1185613 non-null  object
#  4   vehicle_id             1172146 non-null  float64
#  5   crash_date             1195747 non-null  object
#  6   seat_no                244512 non-null   float64
#  7   city                   879728 non-null   object
#  8   state                  890189 non-null   object
#  9   zipcode                803192 non-null   object
#  10  sex                    1177665 non-null  object
#  11  age                    852450 non-null   float64
#  12  drivers_license_state  705542 non-null   object
#  13  drivers_license_class  608027 non-null   object
# ...

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107267 entries, 0 to 1107266
# Data columns (total 72 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   crash_unit_id             1107267 non-null  int64
#  1   crash_record_id           1107267 non-null  object
#  2   rd_no                     1097786 non-null  object
#  3   crash_date                1107267 non-null  object
#  4   unit_no                   1107267 non-null  int64
#  5   unit_type                 1105670 non-null  object
#  6   num_passengers            165920 non-null   float64
#  7   vehicle_id                1081934 non-null  float64
#  8   cmrc_veh_i                20475 non-null    object
#  9   make                      1081929 non-null  object
#  10  model                     1081786 non-null  object
#  11  lic_plate_state           987487 non-null   object
#  12  vehicle_year              905696 non-null   float64
# ...

# %%
df_crashes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541142 entries, 0 to 541141
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_record_id                541142 non-null  object
#  1   rd_no                          536550 non-null  object
#  2   crash_date_est_i               41029 non-null   object
#  3   crash_date                     541142 non-null  object
#  4   posted_speed_limit             541142 non-null  int64
#  5   traffic_control_device         541142 non-null  object
#  6   device_condition               541142 non-null  object
#  7   weather_condition              541142 non-null  object
#  8   lighting_condition             541142 non-null  object
#  9   first_crash_type               541142 non-null  object
#  10  trafficway_type                541142 non-null  object
#  11  lane_cnt                       198968 non-null  float64
# ...

# %%
severe_injuries = df_crashes[(df_crashes['injuries_incapacitating'] >= 1) + (df_crashes['injuries_fatal'] >= 1)]
severe_injuries
# Out:
# C:\Users\sethk\anaconda3\envs\learn-env\lib\site-packages\pandas\core\computation\expressions.py:203: UserWarning: evaluating in Python space because the '+' operator is not supported by numexpr for the bool dtype, use '|' instead
#   warnings.warn(
#                                                                                                                          crash_record_id  \
# 31      09eba71804d41a145cbf5423f5a6a99fe8e8e08d4f475793b1a008aa4f7c62126e1ff704918e4d6c69d05647c02c4a509e981ae6a448297957c7ce591237b163
# 93      1d6129948f25958aaa828c48f46ede1d07d9a14a29431fb552bf464bbfccbe5a6f1b9da6f4ee75d6de1b9f6d0aefc8be2e425fa1eb7435a30c2145c94f231686
# 95      1ec7df5197ad2c75687061922a58daaedf81612ff92be2a595fc1aabda88b5fa112eec18751018249c440ccd9f2e93d90f961838b44c8db0cabffd6ad2327940
# 258     6a753aacc3c712fae192f3a1ab2e326dfbe9201ea37cfa42d302aac7388a01e0240253fb13cb545097bc4d0a27a35cc178b14249456ce488f90dfda1773d68a0
# ...

# %%
df_crashes['injuries_fatal'].value_counts()
# Out:
# 0.0    539483
# 1.0       510
# 2.0        31
# 3.0         5
# 4.0         1
# Name: injuries_fatal, dtype: int64

# %%
df_ppl['driver_action'].value_counts()
# Out:
# NONE                                 344715
# UNKNOWN                              227765
# FAILED TO YIELD                       87804
# OTHER                                 81985
# FOLLOWED TOO CLOSELY                  60871
# IMPROPER BACKING                      30203
# IMPROPER TURN                         25163
# IMPROPER LANE CHANGE                  25019
# IMPROPER PASSING                      21036
# DISREGARDED CONTROL DEVICES           15881
# TOO FAST FOR CONDITIONS               15406
# IMPROPER PARKING                       3690
# WRONG WAY/SIDE                         3650
# CELL PHONE USE OTHER THAN TEXTING      1579
# EVADING POLICE VEHICLE                 1569
# OVERCORRECTED                          1144
# EMERGENCY VEHICLE ON CALL               918
# TEXTING                                 416
# STOPPED SCHOOL BUS                      105
# LICENSE RESTRICTIONS                     43
# Name: driver_action, dtype: int64

# %%
prim = df_crashes['prim_contributory_cause']
prim.value_counts()
# Out:
# UNABLE TO DETERMINE                                                                 202539
# FAILING TO YIELD RIGHT-OF-WAY                                                        59072
# FOLLOWING TOO CLOSELY                                                                56183
# NOT APPLICABLE                                                                       29030
# IMPROPER OVERTAKING/PASSING                                                          25754
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               23420
# IMPROPER BACKING                                                                     23249
# IMPROPER LANE USAGE                                                                  20576
# IMPROPER TURNING/NO SIGNAL                                                           17895
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  17175
# ...

# %%
df_crashes['weather_condition'].value_counts()
# Out:
# CLEAR                       430466
# RAIN                         46498
# UNKNOWN                      23856
# SNOW                         20313
# CLOUDY/OVERCAST              15882
# OTHER                         1660
# FOG/SMOKE/HAZE                 844
# SLEET/HAIL                     722
# FREEZING RAIN/DRIZZLE          628
# BLOWING SNOW                   166
# SEVERE CROSS WIND GATE         105
# BLOWING SAND, SOIL, DIRT         2
# Name: weather_condition, dtype: int64

# %%
sped = df_cars['exceed_speed_limit_i']
sped.value_counts()
# Out:
# Y    1796
# N     596
# Name: exceed_speed_limit_i, dtype: int64

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107267 entries, 0 to 1107266
# Data columns (total 72 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   crash_unit_id             1107267 non-null  int64
#  1   crash_record_id           1107267 non-null  object
#  2   rd_no                     1097786 non-null  object
#  3   crash_date                1107267 non-null  object
#  4   unit_no                   1107267 non-null  int64
#  5   unit_type                 1105670 non-null  object
#  6   num_passengers            165920 non-null   float64
#  7   vehicle_id                1081934 non-null  float64
#  8   cmrc_veh_i                20475 non-null    object
#  9   make                      1081929 non-null  object
#  10  model                     1081786 non-null  object
#  11  lic_plate_state           987487 non-null   object
#  12  vehicle_year              905696 non-null   float64
# ...

# %%
df_ppl['injury_classification'].value_counts()
# Out:
# NO INDICATION OF INJURY     1096283
# NONINCAPACITATING INJURY      55296
# REPORTED, NOT EVIDENT         32092
# INCAPACITATING INJURY         10827
# FATAL                           656
# Name: injury_classification, dtype: int64

# %%
df_not_severe = df_ppl[(df_ppl['injury_classification'] != "INCAPACITATING INJURY") & (df_ppl['injury_classification'] != "FATAL")]

# %%
df_severe = df_ppl[(df_ppl['injury_classification'] == "INCAPACITATING INJURY") | (df_ppl['injury_classification'] == "FATAL")]
df_severe
# Out:
#         person_id person_type  \
# 102       P193979   PASSENGER
# 124       O880468      DRIVER
# 172       O837935      DRIVER
# 308       O838234  PEDESTRIAN
# 504       O838563      DRIVER
# ...           ...         ...
# 1195495  O1170843      DRIVER
# 1195500  O1170857  PEDESTRIAN
# 1195532  O1170903      DRIVER
# 1195630  O1171055      DRIVER
# 1195737   P262482   PASSENGER
#
#                                            crash_record_id     rd_no  \
# 102      883894fdf3e34b8da6aec050ca860213fc5f6657714684...  JD161663
# 124      b25489278fb5b3ff0c61c1cdfd93028308c8879639caa6...  JD226210
# 172      a8405fd5fb5ec1a8b80143f139e248d72c9bb630278936...  JD144213
# 308      d14abcac0d5211556093b27f866291121caa2f50c6b71b...  JD144622
# 504      362c12430744ace0e1bd90e95689790166481ef62c096f...  JD145123
# ...                                                    ...       ...
# 1195495  04eccb444de65cd5ffaa3cf12be785ddc661d99b3ca977...  JE352203
# ...

# %%
df_speed = df_ppl[df_ppl['driver_action'] == 'TOO FAST FOR CONDITIONS']
df_speed
# Out:
#         person_id person_type  \
# 26         O10153      DRIVER
# 123       O880467      DRIVER
# 187       O837960      DRIVER
# 196       O837975      DRIVER
# 269       O838143      DRIVER
# ...           ...         ...
# 1195253  O1170494      DRIVER
# 1195405  O1170723      DRIVER
# 1195444  O1170773      DRIVER
# 1195495  O1170843      DRIVER
# 1195713  O1174276      DRIVER
#
#                                            crash_record_id     rd_no  \
# 26       2659c4a1941557817b6121590ff878bd3a5777c19c6bb5...  HY485721
# 123      b25489278fb5b3ff0c61c1cdfd93028308c8879639caa6...  JD226210
# 187      6a46d4b4ea4baf6f78a5fc203b33ef3156cf3c9dc1cfb9...  JD144267
# 196      a82668dfee09513175d4ccc4a4bc75253f86f77c2f469a...  JD144271
# 269      fcfaf3097299e3d76eb573ec931bfb7a6b8bf27d5f9c86...  JD144549
# ...                                                    ...       ...
# 1195253  f4bd63f5ea715e05667c610d318aab40f687ad3d044cc7...  JE351764
# ...

# %%
df_fatal_speed = df_speed[(df_speed['injury_classification'] == "INCAPACITATING INJURY") | (df_speed['injury_classification'] == "FATAL")]
df_fatal_speed
# Out:
#         person_id person_type  \
# 2480      O839354      DRIVER
# 4189      O875545      DRIVER
# 10062     O853602      DRIVER
# 10319     O876691      DRIVER
# 10326     O876692      DRIVER
# ...           ...         ...
# 1181979  O1110240     BICYCLE
# 1183987  O1111215      DRIVER
# 1184354  O1111864      DRIVER
# 1186728  O1113946      DRIVER
# 1195495  O1170843      DRIVER
#
#                                            crash_record_id     rd_no  \
# 2480     7db21a448e6a41b5093da3a35a6f4ec636895d13411407...  JD146349
# 4189     a040ed4cc15d103136e962519e44c3f7d0da8aa7e5031b...  JD215837
# 10062    08d8b1747ca790951f856dcd6bf1e45aebf16cc6a0b5d1...  JD170887
# 10319    798935ff8dedc14e9a493312384bb2ea89a90208f0fb17...  JD218845
# 10326    798935ff8dedc14e9a493312384bb2ea89a90208f0fb17...  JD218845
# ...                                                    ...       ...
# 1181979  adb2e3cde0d6f09d03e868ee7087e77fb5a947aad181f2...  JE254006
# ...

# %%
df_ppl['zipcode'].value_counts()
# Out:
# 60629         29045
# 60639         24461
# 60620         22501
# 60617         21238
# 60619         20689
#               ...
# 36206             1
# 32548             1
# 49417-9649        1
# 17103             1
# 33950             1
# Name: zipcode, Length: 11633, dtype: int64

# %%
df_cars.sample(5)
# Out:
#         crash_unit_id                                    crash_record_id  \
# 388584         305132  bddd04040cf73e15a428ef8ec3b07ee1a74e12cf66c574...
# 882093         796326  01b296d0e0c4cac213485f86cb6543629d87d076483cc9...
# 286301         204995  0c1a61f6d1f25de0e838d50c28e9f14a42adf1404bd2dc...
# 354866         272143  e47be567356eb5cd00b34718397ca88a6db50a0a0be05b...
# 133588         927791  5f33ed89441437109beb1a95be3b8ad37122d23a841e92...
#
#            rd_no              crash_date  unit_no   unit_type  num_passengers  \
# 388584  JB118286  01/16/2018 04:42:00 PM        2      DRIVER             1.0
# 882093  JC536352  12/05/2019 12:55:00 AM        2      PARKED             NaN
# 286301  JA404848  08/24/2017 05:30:00 PM        2  DRIVERLESS             NaN
# 354866  JA532138  12/01/2017 10:30:00 AM        2      DRIVER             NaN
# 133588  JD314229  07/29/2020 04:25:00 PM        2      DRIVER             NaN
#
# ...

# %%
crashes_test_df = df_crashes[df_crashes['crash_record_id'] == '2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa70f59b967340b7d46b345e7d62a9a3c60c9b5a086a21363ef2aec59cfe8b1240db2b3e26e2b1890ced5']
crashes_test_df
# Out:
#                                           crash_record_id     rd_no  \
# 109381  2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa7...  JC364121
#
#        crash_date_est_i              crash_date  posted_speed_limit  \
# 109381              NaN  07/25/2019 01:50:00 PM                  30
#
#        traffic_control_device device_condition weather_condition  \
# 109381            NO CONTROLS      NO CONTROLS             CLEAR
#
#        lighting_condition first_crash_type trafficway_type  lane_cnt  \
# 109381           DAYLIGHT    REAR TO FRONT         ONE-WAY       NaN
#
#                  alignment roadway_surface_cond road_defect report_type  \
# 109381  STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
#
#                     crash_type intersection_related_i not_right_of_way_i  \
# 109381  NO INJURY / DRIVE AWAY                    NaN                NaN
#
#        hit_and_run_i        damage    date_police_notified  \
# ...

# %%
ppl_test_df = df_ppl[df_ppl['crash_record_id'] == '2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa70f59b967340b7d46b345e7d62a9a3c60c9b5a086a21363ef2aec59cfe8b1240db2b3e26e2b1890ced5']
ppl_test_df
# Out:
#        person_id person_type  \
# 735100   O701976      DRIVER
# 735101   O701977      DRIVER
# 920092   P160165   PASSENGER
#
#                                           crash_record_id     rd_no  \
# 735100  2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa7...  JC364121
# 735101  2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa7...  JC364121
# 920092  2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa7...  JC364121
#
#         vehicle_id              crash_date  seat_no        city state zipcode  \
# 735100    667679.0  07/25/2019 01:50:00 PM      NaN  GLEN ELLYN    IL   60137
# 735101    667670.0  07/25/2019 01:50:00 PM      NaN     CHICAGO    IL   60657
# 920092    667679.0  07/25/2019 01:50:00 PM      3.0         NaN    IL     NaN
#
#        sex   age drivers_license_state drivers_license_class  \
# 735100   M  31.0                    IL                     D
# 735101   M  24.0                    IL                     D
# 920092   M  36.0                   NaN                   NaN
#
# ...

# %%
test_df = df_cars[df_cars['crash_record_id'] == '2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa70f59b967340b7d46b345e7d62a9a3c60c9b5a086a21363ef2aec59cfe8b1240db2b3e26e2b1890ced5']
test_df
# Out:
#         crash_unit_id                                    crash_record_id  \
# 787189         701976  2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa7...
# 787190         701977  2516d2834ff7c4b0b945e116ba642c6150e08470aa7aa7...
#
#            rd_no              crash_date  unit_no unit_type  num_passengers  \
# 787189  JC364121  07/25/2019 01:50:00 PM        1    DRIVER             1.0
# 787190  JC364121  07/25/2019 01:50:00 PM        2    DRIVER             NaN
#
#         vehicle_id cmrc_veh_i  make                    model lic_plate_state  \
# 787189    667679.0          N  FORD  FORD-TRUCK,VAN,SUV, ETC              IL
# 787190    667670.0        NaN  FORD                    Focus              IL
#
#         vehicle_year vehicle_defect         vehicle_type  \
# 787189        2005.0           NONE  TRUCK - SINGLE UNIT
# 787190        2018.0           NONE            PASSENGER
#
#                      vehicle_use travel_direction        maneuver towed_i  \
# ...

# %%
hazmat = df_cars[df_cars['hazmat_present_i'] == 'Y']
hazmat
# Out:
#         crash_unit_id                                    crash_record_id  \
# 289861         208545  ea13978e11d7f599aed736cacd710162a1118303c572c2...
# 308792         226998  8f74717d6d29b3f310f007e5da4c11b595c545b701c5b9...
# 323788         241593  5c53d329630e12a5f1152554c48cda61d3fa2d06099eb9...
# 427766         343590  c37ec2b94edc21730b5346a25b57e2b2e22f0745e5e57e...
# 553113         467525  81f5825f81d4cbafe8489adac94ed9f94b3a14c8022ff2...
# 622753         536981  75e829cbbb50f79ed3abf8128b62e19b341b63ea64c86b...
# 664083          57853  441d921347beed1dcc3f50ff6c61c702b043386ce8aa1b...
# 715028         629807  7f8bcb161baa080dfea66b8aeda8c8547bfb393aa4030a...
# 722088         636874  947064198308a958a59612cddf368bcda6d28b308f1436...
# 764781         679420  906855b7f62b8cee877437697af8e39fb287caf54833de...
# 810927         725732  dbb7f89fdeb863a7bf0e8aa948422ec78934b67ba6ee9f...
# 811521         726310  fb51a68fe62c071bd73f2d28d6e2bac4ba8bb578d4e611...
# ...

# %%
df_cars['area_00_i'].value_counts()
# Out:
# Y    36280
# N     5394
# Name: area_00_i, dtype: int64

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107267 entries, 0 to 1107266
# Data columns (total 72 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   crash_unit_id             1107267 non-null  int64
#  1   crash_record_id           1107267 non-null  object
#  2   rd_no                     1097786 non-null  object
#  3   crash_date                1107267 non-null  object
#  4   unit_no                   1107267 non-null  int64
#  5   unit_type                 1105670 non-null  object
#  6   num_passengers            165920 non-null   float64
#  7   vehicle_id                1081934 non-null  float64
#  8   cmrc_veh_i                20475 non-null    object
#  9   make                      1081929 non-null  object
#  10  model                     1081786 non-null  object
#  11  lic_plate_state           987487 non-null   object
#  12  vehicle_year              905696 non-null   float64
# ...
